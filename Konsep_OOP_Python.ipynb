# %% [markdown]
# <a href="https://colab.research.google.com/github/zahraaurel/TugasKKA/blob/main/Konsep_OOP_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Membuat class Hero latihan 1
class Hero:
    # Constructor: dijalankan saat object Hero dibuat
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    # Method untuk menampilkan info hero
    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")


# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

# Mengubah HP hero1
hero1.hp = 500

# Menampilkan HP hero1 saja
print(hero1.hp)

# Memanggil Method info
hero1.info()
hero2.info()
# Out:
# 500
# Hero: Layla | HP: 500 | Power: 15
# Hero: Zilong | HP: 120 | Power: 20

# %%
# Membuat class Hero latihan 2
class Hero:
    # Constructor
    def __init__(self, name, hp, attack_power):
        self.name = name              # Nama Hero
        self.hp = hp                  # Health Point
        self.attack_power = attack_power  # Kekuatan Serangan

    # Method menampilkan info hero
    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")

    # Method menyerang hero lain
    def serang(self, lawan):
        print(f"{self.name} menyerang {lawan.name}!")
        lawan.diserang(self.attack_power)

    # Method menerima serangan
    def diserang(self, damage):
        self.hp -= damage
        print(f"{self.name} terkena damage {damage}. Sisa HP: {self.hp}")


# --- Main Program ---

# Membuat objek Hero
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

# Menampilkan info awal
hero1.info()
hero2.info()

print("\n--- Pertarungan Dimulai ---")

# Pertarungan
hero1.serang(hero2)   # Layla menyerang Zilong
hero2.serang(hero1)   # Zilong membalas

print("\n--- Info Akhir ---")
hero1.info()
hero2.info()
# Out:
# Hero: Layla | HP: 100 | Power: 15
# Hero: Zilong | HP: 120 | Power: 20
#
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP: 105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP: 80
#
# --- Info Akhir ---
# Hero: Layla | HP: 80 | Power: 15
# Hero: Zilong | HP: 105 | Power: 20

# %%
# latihan 3
class Hero:
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")

    def serang(self, lawan):
        print(f"{self.name} menyerang {lawan.name}!")
        lawan.diserang(self.attack_power)

    def diserang(self, damage):
        self.hp -= damage
        print(f"{self.name} terkena damage {damage}. Sisa HP: {self.hp}")


# ======================
# Child Class (Inheritance)
# ======================
class Mage(Hero):
    def __init__(self, name, hp, attack_power, mana):
        # Memanggil constructor Parent (Hero)
        super().__init__(name, hp, attack_power)
        self.mana = mana

    def info(self):
        print(f"{self.name} [Mage] | HP: {self.hp} | Mana: {self.mana}")

    # Skill khusus Mage
    def skill_fireball(self, lawan):
        if self.mana >= 20:
            print(f"{self.name} menggunakan Fireball ke {lawan.name}!")
            self.mana -= 20
            lawan.diserang(self.attack_power * 2)
        else:
            print(f"{self.name} gagal skill! Mana tidak cukup.")


# ======================
# Main Program
# ======================
print("\n--- Update Class Hero ---")

eudora = Mage("Eudora", 80, 30, 100)
balmond = Hero("Balmond", 200, 10)

eudora.info()
eudora.serang(balmond)        # Method warisan dari Hero
eudora.skill_fireball(balmond)
# Out:
# --- Update Class Hero ---
# Eudora [Mage] | HP: 80 | Mana: 100
# Eudora menyerang Balmond!
# Balmond terkena damage 30. Sisa HP: 170
# Eudora menggunakan Fireball ke Balmond!
# Balmond terkena damage 60. Sisa HP: 110

# %%
#latihan 4
# ==================================
# Class Hero (Encapsulation)
# ==================================
class Hero:
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.__hp = hp              # PRIVATE attribute
        self.attack_power = attack_power

    # Getter
    def get_hp(self):
        return self.__hp

    # Setter (AWALNYA DENGAN VALIDASI)
    def set_hp(self, nilai_baru):
        if nilai_baru < 0:
            print("HP tidak boleh negatif!")
        else:
            self.__hp = nilai_baru

    def info(self):
        print(f"Hero: {self.name} | HP: {self.__hp} | Power: {self.attack_power}")


# ==================================
# Main Program
# ==================================
hero1 = Hero("Layla", 100, 15)

print("\n--- INFO AWAL ---")
hero1.info()

# ==================================
# 1. PERCOBAAN HACKING (NAME MANGLING)
# ==================================
print("\n--- PERCOBAAN HACKING ---")
print(f"Mencoba akses paksa: {hero1._Hero__hp}")

# ==================================
# 2. UJI VALIDASI SETTER
# (SIMULASI: LOGIKA VALIDASI DIHAPUS)
# ==================================

# Setter TANPA validasi (MENIRU KESALAHAN)
def set_hp_tanpa_validasi(self, nilai_baru):
    self.__hp = nilai_baru

# Mengganti method set_hp dengan versi tanpa validasi
Hero.set_hp = set_hp_tanpa_validasi

print("\n--- UJI SETTER TANPA VALIDASI ---")
hero1.set_hp(-100)   # HP negatif
hero1.info()
# Out:
# --- INFO AWAL ---
# Hero: Layla | HP: 100 | Power: 15
#
# --- PERCOBAAN HACKING ---
# Mencoba akses paksa: 100
#
# --- UJI SETTER TANPA VALIDASI ---
# Hero: Layla | HP: 100 | Power: 15

# %%
from abc import ABC, abstractmethod

# 1. Abstract Class / Interface
# (Blueprint / Kontrak)

class GameUnit(ABC):

    @abstractmethod
    def serang(self, target):
        pass

    @abstractmethod
    def info(self):
        pass

# 2. Implementasi pada Class Hero

class Hero(GameUnit):
    def __init__(self, nama):
        self.nama = nama

    # Wajib implementasi method serang
    def serang(self, target):
        print(f"Hero {self.nama} menebas {target}!")

    # Wajib implementasi method info
    def info(self):
        print(f"Saya adalah Hero: {self.nama}")

# 3. Implementasi pada Class Monster

class Monster(GameUnit):
    def __init__(self, jenis):
        self.jenis = jenis

    # Implementasi serang versi Monster
    def serang(self, target):
        print(f"Monster {self.jenis} menggigit {target}!")

    # Implementasi info versi Monster
    def info(self):
        print(f"Saya adalah Monster: {self.jenis}")

h = Hero("Alucard")
m = Monster("Serigala")

h.info()
m.info()

h.serang("Monster")
m.serang("Hero")
# Out:
# Saya adalah Hero: Alucard
# Saya adalah Monster: Serigala
# Hero Alucard menebas Monster!
# Monster Serigala menggigit Hero!
